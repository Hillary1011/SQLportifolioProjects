# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8)

# Reading the data 
data = pd.read_csv(r'C:\Users\NUIST32\Documents\Untitled Folder\movies.csv')
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
for col in data.columns:
    pcnt_missing = np.mean(data[col].isnull())
    print(f"{col} - {round(pcnt_missing, 6)}%" len())
# Out:
# name - 0.0%
# rating - 0.010042%
# genre - 0.0%
# year - 0.0%
# released - 0.000261%
# score - 0.000391%
# votes - 0.000391%
# director - 0.0%
# writer - 0.000391%
# star - 0.00013%
# country - 0.000391%
# budget - 0.283125%
# gross - 0.024648%
# company - 0.002217%
# runtime - 0.000522%

# %%
data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Dropping NA values
c_data = data.dropna()

# %%
# Converting datatypes to int type
c_data["budget"]  = c_data["budget"].astype("int64")
c_data["gross"] = c_data["gross"].astype("int64")

# %%
c_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# ## Data Cleaning on company feature

# %%
# Dropping duplicates 
print(len(c_data["company"].drop_duplicates()), len(c_data))

c_data["company"].drop_duplicates()
# Observed dupicates in dataset value count = 5421 - 1475 ,, Total 3946 records removed
# Out:
# 1476 5421
# 0                              Warner Bros.
# 1                         Columbia Pictures
# 2                                 Lucasfilm
# 3                        Paramount Pictures
# 4                            Orion Pictures
#                        ...
# 7604                         Emphatic Films
# 7616                 Hicktown Entertainment
# 7645                Clubhouse Pictures (II)
# 7651                   20th Century Studios
# 7652    Beijing Diqi Yinxiang Entertainment
# Name: company, Length: 1476, dtype: object

# %% [markdown]
# What features are the most corelated to the gross feature ?

# %% [markdown]
# hypothsis: budget --> gross,    votes ?

# %%
c_data.sort_values(by="budget", ascending=False).head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score     votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000.0   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000.0   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000.0    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000.0     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000.0  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %%
# Scatter Plot (budget Vs gross)
plt.scatter(x=c_data["budget"], y=c_data["gross"])
plt.title("budget Vs gross")
plt.xlabel("budget")
plt.ylabel("gross")
plt.show()


# ax = plt.gca()
# ax.scatter(c_data["budget"],c_data["gross"])
# ax.set_yscale('log')
# ax.set_xscale('log')
# plt.title("budget Vs gross")
# plt.xlabel("gross")
# plt.ylabel("budget")
# plt.show()

# %% [markdown]
# Reggression plot of budget vs Gross

# %%
# 
sns.regplot(x="budget", y="gross", data=c_data, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %% [markdown]
# Evaluating Corelation

# %%
c_data.corr()  # Pearson correlation
# c_data.corr(method="kendall")              # Kendal
# c_data.corr(method="spearman")              # spearman
# c_data[["budget", "gross"]].corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# Observation:
# High correlation of 0.740247 between budget and gross

# %%
corr_matrix = c_data.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation Matrix of Neumeric features")
plt.xlabel("Movie Feature")
plt.ylabel("Movie Feature")
plt.show()

# %%
corr_pairs = corr_matrix.unstack()
corr_pairs
# Out:
# year     year       1.000000
#          score      0.056386
#          votes      0.206021
#          budget     0.327722
#          gross      0.274321
#          runtime    0.075077
# score    year       0.056386
#          score      1.000000
#          votes      0.474256
#          budget     0.072001
#          gross      0.222556
#          runtime    0.414068
# votes    year       0.206021
#          score      0.474256
#          votes      1.000000
#          budget     0.439675
#          gross      0.614751
#          runtime    0.352303
# budget   year       0.327722
#          score      0.072001
#          votes      0.439675
#          budget     1.000000
#          gross      0.740247
#          runtime    0.318695
# gross    year       0.274321
#          score      0.222556
#          votes      0.614751
#          budget     0.740247
#          gross      1.000000
#          runtime    0.275796
# runtime  year       0.075077
#          score      0.414068
# ...

# %%
corr_pairs.sort_values()
# Out:
# year     score      0.056386
# score    year       0.056386
# budget   score      0.072001
# score    budget     0.072001
# year     runtime    0.075077
# runtime  year       0.075077
# year     votes      0.206021
# votes    year       0.206021
# gross    score      0.222556
# score    gross      0.222556
# year     gross      0.274321
# gross    year       0.274321
#          runtime    0.275796
# runtime  gross      0.275796
# budget   runtime    0.318695
# runtime  budget     0.318695
# year     budget     0.327722
# budget   year       0.327722
# votes    runtime    0.352303
# runtime  votes      0.352303
#          score      0.414068
# score    runtime    0.414068
# votes    budget     0.439675
# budget   votes      0.439675
# votes    score      0.474256
# score    votes      0.474256
# gross    votes      0.614751
# votes    gross      0.614751
# budget   gross      0.740247
# gross    budget     0.740247
# year     year       1.000000
# budget   budget     1.000000
# ...
